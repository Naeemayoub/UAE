# %%
import tensorflow as tf
import cv2
import numpy as np
from model import outlier_model
from AE_utils import mse, reshape, CheckAnomaly

# %%
img_width, img_height = 220, 220
model = outlier_model(img_width, img_height)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 220, 220, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 220, 220, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 110, 110, 32)      18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 55, 55, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 55, 55, 16)        4624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 16)        0
# ...

# %%
model.load_weights('recons_det.h5');

# %%
org_img = 'img_data/train/insolator_1/insov1-12.png'
validation_img = 'img_data/insov1-1.png'
CheckAnomaly(model, org_img, validation_img, img_width, img_height, threshold=0.04)
# Out:
# validate_mse: 0.01622630382012715
# Test_mse: 0.20860009804903637
# Image is anomalous
# True

# %%
org_img = 'img_data/train/insolator_1/insov1-12.png'
validation_img = 'img_data/train/insolator_1/insov1-12.png'
CheckAnomaly(model, org_img, validation_img, img_width, img_height, threshold=0.04)
# Out:
# validate_mse: 0.01622630382012715
# Test_mse: 0.01622630382012715
# Image is not anomalious
# False
